# %% [markdown]
# <a href="https://colab.research.google.com/github/Reematechcampus19/LanaProject/blob/main/Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Assignment  Create and Share Your Jupyter Notebook**

# %% [markdown]
# # introduction:
#
# *   Create a Jupyter Notebook
# *   Insert code and markdown cells
# *   Share your notebook through GitHub

# %% [markdown]
# list data science languages:
#
# *   Python
# *   SQL
# *   Java
# *   Julia
# *   Scala
# *   JavaScript

# %% [markdown]
# list data science libraries:
#
# *   TensorFlow
# *   NumPy
# *   SciPy
# *   Pandas
# *   Matplotlib
# *   Keras
# *   SciKit-Learn

# %% [markdown]
#  Data Science tools:
#  <table>
#   <tr>
#     <th>Tool</th>
#     <th>Description</th>
#   </tr>
#   <tr>
#     <td><strong>Programming Languages</strong></td>
#     <td></td>
#   </tr>
#   <tr>
#     <td>Python</td>
#     <td>General-purpose language with extensive libraries for data manipulation and analysis.</td>
#   </tr>
#   <tr>
#     <td>R</td>
#     <td>Statistical computing and graphics.</td>
#   </tr>
#   <tr>
#     <td><strong>Data Manipulation & Analysis</strong></td>
#     <td></td>
#   </tr>
#   <tr>
#     <td>Pandas</td>
#     <td>Data manipulation and analysis library for Python.</td>
#   </tr>
#   <tr>
#     <td>NumPy</td>
#     <td>Library for numerical computations in Python.</td>
#   </tr>
#   <tr>
#     <td>RStudio</td>
#     <td>Integrated development environment for R.</td>
#   </tr>
#   <tr>
#     <td><strong>Data Visualization</strong></td>
#     <td></td>
#   </tr>
#   <tr>
#     <td>Matplotlib</td>
#     <td>2D plotting library for Python.</td>
#   </tr>
#   <tr>
#     <td>Seaborn</td>
#     <td>Statistical data visualization based on Matplotlib.</td>
#   </tr>
#   <tr>
#     <td>ggplot2 (R)</td>
#     <td>Data visualization package in R based on the Grammar of Graphics.</td>
#   </tr>
#   <tr>
#     <td>Plotly</td>
#     <td>Interactive and web-based visualization library.</td>
#   </tr>
#   <tr>
#     <td><strong>Machine Learning</strong></td>
#     <td></td>
#   </tr>
#   <tr>
#     <td>Scikit-Learn</td>
#     <td>Simple and efficient tools for data mining and data analysis in Python.</td>
#   </tr>
#   <tr>
#     <td>TensorFlow</td>
#     <td>Open-source library for numerical computation and machine learning.</td>
#   </tr>
#   <tr>
#     <td>Keras</td>
#     <td>High-level neural networks API (can run on top of TensorFlow).</td>
#   </tr>
#   <tr>
#     <td>PyTorch</td>
#     <td>Open-source machine learning framework developed by Facebook.</td>
#   </tr>
#   <tr>
#     <td><strong>Big Data & Distributed Computing</strong></td>
#     <td></td>
#   </tr>
#   <tr>
#     <td>Apache Hadoop</td>
#     <td>Distributed storage and processing of large data sets.</td>
#   </tr>
#   <tr>
#     <td>Apache Spark</td>
#     <td>Open-source cluster-computing framework for big data processing.</td>
#   </tr>
#   <tr>
#     <td><strong>Data Storage & Databases</strong></td>
#     <td></td>
#   </tr>
#   <tr>
#     <td>SQL</td>
#     <td>Domain-specific language for managing and querying relational databases.</td>
#   </tr>
#   <tr>
#     <td>PostgreSQL</td>
#     <td>Open-source relational database system.</td>
#   </tr>
#   <tr>
#     <td>MongoDB</td>
#     <td>NoSQL database for handling large amounts of unstructured data.</td>
#   </tr>
#   <tr>
#     <td><strong>Notebook Environments</strong></td>
#     <td></td>
#   </tr>
#   <tr>
#     <td>Jupyter Notebook</td>
#     <td>Open-source web application for creating and sharing documents with live code, equations, visualizations, and narrative text.</td>
#   </tr>
#   <tr>
#     <td>Google Colab</td>
#     <td>Cloud-based Jupyter Notebook environment provided by Google.</td>
#   </tr>
#   <tr>
#     <td><strong>Version Control</strong></td>
#     <td></td>
#   </tr>
#   <tr>
#     <td>Git</td>
#     <td>Distributed version control system.</td>
#   </tr>
#   <tr>
#     <td>GitHub</td>
#     <td>Web-based hosting service for version control using Git.</td>
#   </tr>
# </table>

# %% [markdown]
# arithmetic expression examples:

# %%
#multiply
2*5
# Out:
# 10

# %%
#add numbers
2+2
# Out:
# 4

# %%
#convert minutes to hours

def minutes_to_hours(minutes):
    hours = minutes / 60
    return hours

minutes = 120
hours = minutes_to_hours(minutes)
print(f"{minutes} minutes is equal to {hours} hours.")
# Out:
# 120 minutes is equal to 2.0 hours.

# %% [markdown]
#  list Objectives:
#
# *   Data Science tool
# *   Data Science libaries
# *   Data Science langages

# %% [markdown]
# Authors name : Reema Alkoshi

# %% [markdown]
# link GitHub:

# %% [markdown]
# screenshot :
# ![Screenshot (523).png](data:image/png;base64,...)![Screenshot (524).png](data:image/png;base64,...)![Screenshot (525).png](data:image/png;base64,...)
